# %%
# !pip install --upgrade yfinance --quiet

# %%
# !git clone "https://github.com/EkantheswarB/risk-aware-deep-rl-trading.git"
# Out:
# fatal: destination path 'risk-aware-deep-rl-trading' already exists and is not an empty directory.

# %%
# %cd /content/risk-aware-deep-rl-trading/
# !pip install -r requirements.txt
# !python src/run_experiment.py
# Out:
# /content/risk-aware-deep-rl-trading
# 2025-10-25 22:34:32.956924: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761431672.997700   14023 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761431673.010062   14023 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761431673.044896   14023 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
